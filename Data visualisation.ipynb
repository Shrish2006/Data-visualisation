# %%
cd Desktop/
# Out:
# C:\Users\user\Desktop

# %%
import pandas as pd
import numpy as np

# %%
f=pd.read_csv("titanic.csv")

# %%
f.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
f.plot(subplots=True);

# %%
x=[x for x in range(0,950,50)]
y=[y for y in range(0,100,20)]

# %% [markdown]
# ### Line graph -> This graph will use to display only date and time based data

# %%
print("Line graph")
f.age.plot(figsize=(15,5),title="Age inspection",xticks=x,yticks=y,fontsize=13,);
# Out:
# Line graph

# %%
f=pd.read_csv("temp.csv",parse_dates=["datetime"])

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35064 non-null  datetime64[ns]
#  1   LA        35062 non-null  float64
#  2   NY        35064 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 821.9 KB

# %%
f.head()
# Out:
#              datetime    LA   NY
# 0 2013-01-01 00:00:00  11.7 -1.1
# 1 2013-01-01 01:00:00  10.7 -1.7
# 2 2013-01-01 02:00:00   9.9 -2.0
# 3 2013-01-01 03:00:00   9.3 -2.1
# 4 2013-01-01 04:00:00   8.8 -2.3

# %%
f.set_index("datetime",inplace=True)

# %%
f.head()
# Out:
#                        LA   NY
# datetime
# 2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00   8.8 -2.3

# %%
f.plot(subplots=True,layout=(1,2),figsize=(20,5),title="Temprature",fontsize=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x18F3BF10>,
# ...
#       dtype=object)

# %%
f=pd.read_csv("titanic.csv")

# %%
f.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
f.age.plot(kind="hist",bins=8)

# %%
x=f.pclass.value_counts()

# %%
x=pd.DataFrame(x)

# %%
x.plot(kind="bar")

# %%
f.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
x=f.loc[:,["age","fare"]]

# %%
x.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
x.plot(kind="scatter",x="age",y="fare",figsize=(20,8),marker="x")

# %% [markdown]
# ## Matplotlib

# %%
f=pd.read_csv("temp.csv",parse_dates=["datetime"],index_col="datetime")

# %%
f.head()
# Out:
#                        LA   NY
# datetime
# 2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00   8.8 -2.3

# %%
import matplotlib.pyplot as pt

# %%
pt.plot(f.LA)
pt.title("Fare",fontsize=20,c="r")
pt.xlabel("Date and time",fontsize=15,c="g")
pt.ylabel("Temperature",fontsize=15,c="g")

pt.plot()
# Out:
# []
